# %% [markdown]
# cd MyDrive/

# %%
# !python service.py > result1.txt

# %%
# !pip install finance-datareader

# %%
cd drive/Mydrive

# %%
cd drive

# %%
# !ls

# %%
cd MyDrive

# %%
cd step3

# %%
# !python service.py > result1.txt

# %%
# !pip install finance-datareader

# %%
# !python service.py > result1.txt

# %%
# !python service.py > result_for_cmp.txt
